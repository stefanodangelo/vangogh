# %% [markdown]
# # Note
# This notebook has been run on Google Colab. If you try to run it locally and you encounter issues, please switch to Colab.

# %% [markdown]
# ## Imports and libraries version adaptation

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install -q 'scipy<=1.2.1'  # scipy.misc.imread is deprecated in later versions

# %%
import os, cv2, shutil, scipy.misc, warnings
from PIL import Image
import matplotlib.pyplot as plt
from math import sqrt 
import numpy as np
from scipy.spatial import distance
from numpy.core.fromnumeric import shape
from google.colab import drive

warnings.filterwarnings("ignore")
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Main network setting

# %%
# !git clone https://github.com/titu1994/Neural-Style-Transfer.git
# Out:
# Cloning into 'Neural-Style-Transfer'...
# remote: Enumerating objects: 1411, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 1411 (delta 5), reused 6 (delta 1), pack-reused 1393
# Receiving objects: 100% (1411/1411), 68.18 MiB | 31.13 MiB/s, done.
# Resolving deltas: 100% (824/824), done.

# %%
nst_path = "Neural-Style-Transfer"

## Network type
NETWORK = 'INetwork' + '.py'

## Network parameters
# Loss Weights
CONTENT_WEIGHT = 0.025
STYLE_WEIGHT = 1.0
STYLE_SCALE = 1.0
TOTAL_VARIATION_WEIGHT = 8.5e-5
CONTENT_LOSS_TYPE = 0

# Training arguments
NUM_ITERATIONS = 10
MODEL = 'vgg19'
RESCALE_IMAGE = 'false'
MAINTAIN_ASPECT_RATIO = 'false'  # Set to false if OOM occurs

# Transfer Arguments
CONTENT_LAYER = 'conv' + '5_2'  # only change the number 5_2 to something in a similar format
INITIALIZATION_IMAGE = 'content'
POOLING_TYPE = 'max'

# Extra arguments
PRESERVE_COLOR = 'false'
MIN_IMPROVEMENT = 0.0

# %% [markdown]
# ## Helper methods definition

# %%
def crop(img, n_patches = 16):
    offset = int(sqrt(n_patches))
    width = img.size[0]
    height = img.size[1]
    patches = []
    
    for h in range(offset):
        for w in range(offset):
            area = (h * (height//offset), w * (width//offset), (h+1) * (height//offset), (w+1) * (width//offset))
            patches.append(img.crop(area))
    
    return patches

def calc_closest_val(values, checkMax=False):
    if (checkMax):
        closest = max(values)
    else:
        closest = min(values)
    
    return values.index(closest)

def compute_distances(img, patches, compute_eucl=True, compute_manhat=True, compute_vca=True, excluded_imgs=[]):
    dim = (4, 4)
    test_img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

    eucl_dist = []
    manhat_dist = []
    vca_dist = []
    
    for patch in patches:
        resized_img = cv2.resize(np.array(patch), dim, interpolation = cv2.INTER_AREA)
        
        # Compute distances only for images that have not been paired yet
        if img not in excluded_imgs:
            if compute_eucl:
                eucl_dist.append(distance.euclidean(test_img.flatten(), resized_img.flatten()))
            if compute_manhat:
                manhat_dist.append(distance.cityblock(test_img.flatten(), resized_img.flatten()))
            if compute_vca:
                vca_dist.append(distance.cosine(test_img.flatten(), resized_img.flatten()))
    
    return calc_closest_val(eucl_dist), calc_closest_val(manhat_dist), calc_closest_val(vca_dist, True)

def show_img(img, title=''):
  if type(img) == str:
    img = plt.imread(img)

  plt.axis('off')
  plt.title(title)
  plt.imshow(img)
  plt.show()

def transfer_style(crop_number, result_dir, content_fn, style_fn):
  RESULT_DIR = os.path.join(result_dir, "generated/")
  RESULT_PREFIX = RESULT_DIR + "%d_gen" % (crop_number)
  FINAL_IMAGE_PATH = RESULT_PREFIX + "_at_iteration_%d.png" % (NUM_ITERATIONS)

  if not os.path.exists(RESULT_DIR):
    os.makedirs(RESULT_DIR)

  run_nst_script(RESULT_PREFIX, content_fn, style_fn)

  return RESULT_DIR, FINAL_IMAGE_PATH

def run_nst_script(result_prefix, content_fn, style_fn):
  # %%shell
  # !python {nst_path}/{NETWORK} {content_fn} {style_fn} {result_prefix} \
    --image_size {IMAGE_SIZE} --content_weight {CONTENT_WEIGHT} --style_weight \
    {STYLE_WEIGHT} --style_scale {STYLE_SCALE} --total_variation_weight \
    {TOTAL_VARIATION_WEIGHT} --content_loss_type {CONTENT_LOSS_TYPE} --num_iter \
    {NUM_ITERATIONS} --model {MODEL} --rescale_image {RESCALE_IMAGE} \
    --maintain_aspect_ratio {MAINTAIN_ASPECT_RATIO} --content_layer {CONTENT_LAYER} \
    --init_image {INITIALIZATION_IMAGE} --pool_type {POOLING_TYPE} --preserve_color \
    {PRESERVE_COLOR} --min_improvement {MIN_IMPROVEMENT}

# %%
def transfer_color(path, content_fn):
  COLOR_TRANSFER = 'color_transfer.py'
  COLOR_FINAL_IMAGE_PATH = path + '_%s_color.png'

  # Optional - Use Histogram matching (0 for no, 1 for yes)
  HISTOGRAM_MATCH = 0

  if HISTOGRAM_MATCH == 0:
    COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('original')
  else:
    COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('histogram')
    
  # %%shell
  # !python {nst_path}/{COLOR_TRANSFER} {content_fn} {path} --hist_match {HISTOGRAM_MATCH}

# %%
def reconstruct(crops, base_dir, save_path, grid_height):
  col = 0
  reconstructed_img = None

  for c in range(col, len(crops), grid_height):
    vertical_reconstruction = plt.imread(os.path.join(base_dir, crops[c]))

    # stack vertically
    for h in range(1, grid_height):
      img = plt.imread(os.path.join(base_dir, crops[c+h]))
      vertical_reconstruction = np.vstack((vertical_reconstruction, img))

    # stack horizontally
    if reconstructed_img is None:
      reconstructed_img = vertical_reconstruction
    else:
      reconstructed_img = np.hstack((reconstructed_img, vertical_reconstruction))

  scipy.misc.imsave(save_path, reconstructed_img)

# %% [markdown]
# # Style transfer

# %%
n_patches = 9 # it must be a perfect square

base_dir = 'drive/MyDrive/_Van_Gogh/results/'
folders = os.listdir(base_dir)

for f in folders:
  reconstr_dir = os.path.join(base_dir, f, 'reconstructed')
  if not os.path.exists(reconstr_dir):
    os.mkdir(reconstr_dir)
  else: # if directory exists, it means the image has already been processed
    continue
  
  num = f[f.index('_')+1:]

  content_mask = Image.open(os.path.join(base_dir, f, num + '_seg.png'))
  style_mask = Image.open(os.path.join(base_dir, f, num + '_style_seg.png'))
  content_img = Image.open(os.path.join(base_dir, f, num + '.jpg'))
  style_img = Image.open(os.path.join(base_dir, f, num + '_style.jpg'))
  
  IMAGE_SIZE = content_img.size[0] // int(sqrt(n_patches)) # set image size for Neural Style Transfer code

  print("Cropping image " + num)
  print()

  style_crops = crop(style_img, n_patches)
  cropped_content = crop(content_img, n_patches)
  cropped_mask = crop(content_mask, n_patches)

  for i, patch in enumerate(cropped_mask):
    print("\n{:.2f}% completed...\n".format(i*100/len(cropped_mask)))

    # retrieve most similar crop
    ed, md, vcad = compute_distances(np.array(patch), crop(style_mask, n_patches))
    most_sim_style = style_crops[ed] # we use the Euclidean Distance

    # save temporarily both the crops
    temp_content = "content.png"
    temp_style = "style.png"

    cropped_content[i].save(temp_content) # save the content's patch corresponding to the cropped mask
    most_sim_style.save(temp_style)

    # transfer the style from the most similar crop of the style image to the current content patch image
    res_dir, transferred_img = transfer_style(i, os.path.join(base_dir, f), temp_content, temp_style)

    # transfer the color
    transfer_color(transferred_img, temp_content)
  
  print("\n100.00% completed!\n")

  # reconstruct all the crops and save images
  print("Reconstructing images...")

  # reconstruct images generated at every iteration
  for i in range(1, NUM_ITERATIONS+1):
    crops = [img for img in os.listdir(res_dir) if img[img.index("iteration_")+10:].replace(".png", "") == str(i) and 'color' not in img]
    grid_height = int(sqrt(n_patches))

    reconstruct(crops, res_dir, os.path.join(reconstr_dir, num + '_transferred_iteration_%d.jpg' % (i)), grid_height)

  # reconstruct image with color transfer
  crops = [img for img in os.listdir(res_dir) if 'color' in img]
  reconstruct(crops, res_dir, os.path.join(reconstr_dir, num + '_color_transfer.jpg'), grid_height)

  # remove directory with partial results
  shutil.rmtree(res_dir)

  print()
  print("Done!")
  print()
  print()
# Out:
# Cropping image 00440_6
#
#
# 0.00% completed...
#
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 2022-01-05 17:45:05.982495: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-01-05 17:45:06.004802: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:06.005641: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2022-01-05 17:45:06.006013: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:45:06.008345: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:45:06.009573: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-01-05 17:45:06.010036: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-01-05 17:45:06.012434: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-01-05 17:45:06.014983: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-01-05 17:45:06.019445: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-01-05 17:45:06.019613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:06.020435: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:06.021307: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-01-05 17:45:06.027138: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2022-01-05 17:45:06.027428: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x559cc4682fc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-01-05 17:45:06.027473: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-01-05 17:45:06.154941: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:06.156013: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x559cc4683180 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-01-05 17:45:06.156066: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2022-01-05 17:45:06.156292: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:06.157261: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2022-01-05 17:45:06.157382: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:45:06.157468: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:45:06.157537: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-01-05 17:45:06.157653: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-01-05 17:45:06.157757: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-01-05 17:45:06.157822: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-01-05 17:45:06.157896: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-01-05 17:45:06.158045: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:06.158990: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:06.159902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-01-05 17:45:06.159984: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:45:06.161430: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-01-05 17:45:06.161468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2022-01-05 17:45:06.161487: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2022-01-05 17:45:06.161691: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:06.162522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:06.163312: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-01-05 17:45:06.163374: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10813 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Model loaded.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Starting iteration 1 of 10
# 2022-01-05 17:45:11.087643: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:45:11.229079: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Current loss value: 3051648500.0  Improvement : 0.000 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/0_gen_at_iteration_1.png
# Iteration 1 completed in 3s
# Starting iteration 2 of 10
# Current loss value: 1699703900.0  Improvement : 44.302 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/0_gen_at_iteration_2.png
# Iteration 2 completed in 1s
# Starting iteration 3 of 10
# Current loss value: 1163477200.0  Improvement : 31.548 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/0_gen_at_iteration_3.png
# Iteration 3 completed in 1s
# Starting iteration 4 of 10
# Current loss value: 857723100.0  Improvement : 26.279 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/0_gen_at_iteration_4.png
# Iteration 4 completed in 1s
# Starting iteration 5 of 10
# Current loss value: 718685630.0  Improvement : 16.210 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/0_gen_at_iteration_5.png
# Iteration 5 completed in 1s
# Starting iteration 6 of 10
# Current loss value: 643630340.0  Improvement : 10.443 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/0_gen_at_iteration_6.png
# Iteration 6 completed in 1s
# Starting iteration 7 of 10
# Current loss value: 579151000.0  Improvement : 10.018 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/0_gen_at_iteration_7.png
# Iteration 7 completed in 1s
# Starting iteration 8 of 10
# Current loss value: 515413380.0  Improvement : 11.005 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/0_gen_at_iteration_8.png
# Iteration 8 completed in 1s
# Starting iteration 9 of 10
# Current loss value: 469503780.0  Improvement : 8.907 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/0_gen_at_iteration_9.png
# Iteration 9 completed in 1s
# Starting iteration 10 of 10
# Current loss value: 421493200.0  Improvement : 10.226 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/0_gen_at_iteration_10.png
# Iteration 10 completed in 1s
# Neural-Style-Transfer/color_transfer.py:116: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   generated_image = imread(args.generated_image, mode="RGB")
# Neural-Style-Transfer/color_transfer.py:119: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   content_image = imread(args.content_image, mode=mode)
# Neural-Style-Transfer/color_transfer.py:120: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
#     Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   content_image = imresize(content_image, (img_width, img_height), interp='bicubic')
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:129: DeprecationWarning:     `imsave` is deprecated!
#     `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imwrite`` instead.
#   imsave(image_path, img)
# Image saved at path : drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/0_gen_at_iteration_10_original_color.png
#
# 11.11% completed...
#
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 2022-01-05 17:45:29.937323: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-01-05 17:45:29.958882: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:29.959669: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2022-01-05 17:45:29.959969: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:45:29.961764: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:45:29.962724: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-01-05 17:45:29.963051: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-01-05 17:45:29.964888: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-01-05 17:45:29.966017: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-01-05 17:45:29.969681: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-01-05 17:45:29.969794: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:29.970552: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:29.971341: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-01-05 17:45:29.976718: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2022-01-05 17:45:29.976999: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x561d42dc2fc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-01-05 17:45:29.977034: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-01-05 17:45:30.084255: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:30.085197: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x561d42dc3180 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-01-05 17:45:30.085233: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2022-01-05 17:45:30.085417: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:30.086195: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2022-01-05 17:45:30.086270: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:45:30.086315: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:45:30.086361: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-01-05 17:45:30.086408: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-01-05 17:45:30.086456: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-01-05 17:45:30.086505: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-01-05 17:45:30.086546: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-01-05 17:45:30.086651: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:30.087389: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:30.088060: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-01-05 17:45:30.088148: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:45:30.089397: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-01-05 17:45:30.089431: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2022-01-05 17:45:30.089452: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2022-01-05 17:45:30.089612: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:30.090389: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:30.091125: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-01-05 17:45:30.091180: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10813 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Model loaded.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Starting iteration 1 of 10
# 2022-01-05 17:45:35.034117: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:45:35.174107: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Current loss value: 2401572600.0  Improvement : 0.000 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/1_gen_at_iteration_1.png
# Iteration 1 completed in 3s
# Starting iteration 2 of 10
# Current loss value: 1238980400.0  Improvement : 48.410 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/1_gen_at_iteration_2.png
# Iteration 2 completed in 1s
# Starting iteration 3 of 10
# Current loss value: 953673400.0  Improvement : 23.028 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/1_gen_at_iteration_3.png
# Iteration 3 completed in 1s
# Starting iteration 4 of 10
# Current loss value: 816600100.0  Improvement : 14.373 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/1_gen_at_iteration_4.png
# Iteration 4 completed in 1s
# Starting iteration 5 of 10
# Current loss value: 718713860.0  Improvement : 11.987 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/1_gen_at_iteration_5.png
# Iteration 5 completed in 1s
# Starting iteration 6 of 10
# Current loss value: 660617500.0  Improvement : 8.083 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/1_gen_at_iteration_6.png
# Iteration 6 completed in 1s
# Starting iteration 7 of 10
# Current loss value: 620756160.0  Improvement : 6.034 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/1_gen_at_iteration_7.png
# Iteration 7 completed in 1s
# Starting iteration 8 of 10
# Current loss value: 585213000.0  Improvement : 5.726 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/1_gen_at_iteration_8.png
# Iteration 8 completed in 1s
# Starting iteration 9 of 10
# Current loss value: 557285760.0  Improvement : 4.772 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/1_gen_at_iteration_9.png
# Iteration 9 completed in 1s
# Starting iteration 10 of 10
# Current loss value: 532197980.0  Improvement : 4.502 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/1_gen_at_iteration_10.png
# Iteration 10 completed in 1s
# Neural-Style-Transfer/color_transfer.py:116: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   generated_image = imread(args.generated_image, mode="RGB")
# Neural-Style-Transfer/color_transfer.py:119: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   content_image = imread(args.content_image, mode=mode)
# Neural-Style-Transfer/color_transfer.py:120: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
#     Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   content_image = imresize(content_image, (img_width, img_height), interp='bicubic')
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:129: DeprecationWarning:     `imsave` is deprecated!
#     `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imwrite`` instead.
#   imsave(image_path, img)
# Image saved at path : drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/1_gen_at_iteration_10_original_color.png
#
# 22.22% completed...
#
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 2022-01-05 17:45:53.735070: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-01-05 17:45:53.755217: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:53.755961: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2022-01-05 17:45:53.756290: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:45:53.758125: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:45:53.759103: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-01-05 17:45:53.759426: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-01-05 17:45:53.761425: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-01-05 17:45:53.762650: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-01-05 17:45:53.766856: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-01-05 17:45:53.767013: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:53.767865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:53.768658: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-01-05 17:45:53.774344: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2022-01-05 17:45:53.774819: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x556ed2610fc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-01-05 17:45:53.774861: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-01-05 17:45:53.867154: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:53.868077: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x556ed2611180 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-01-05 17:45:53.868115: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2022-01-05 17:45:53.868284: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:53.868994: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2022-01-05 17:45:53.869092: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:45:53.869136: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:45:53.869180: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-01-05 17:45:53.869224: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-01-05 17:45:53.869281: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-01-05 17:45:53.869318: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-01-05 17:45:53.869358: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-01-05 17:45:53.869447: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:53.870167: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:53.870836: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-01-05 17:45:53.870906: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:45:53.872101: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-01-05 17:45:53.872132: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2022-01-05 17:45:53.872155: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2022-01-05 17:45:53.872285: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:53.873097: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:45:53.873828: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-01-05 17:45:53.873881: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10813 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Model loaded.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Starting iteration 1 of 10
# 2022-01-05 17:45:58.810303: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:45:58.959293: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Current loss value: 3121744600.0  Improvement : 0.000 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/2_gen_at_iteration_1.png
# Iteration 1 completed in 3s
# Starting iteration 2 of 10
# Current loss value: 1625676900.0  Improvement : 47.924 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/2_gen_at_iteration_2.png
# Iteration 2 completed in 1s
# Starting iteration 3 of 10
# Current loss value: 1189951900.0  Improvement : 26.803 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/2_gen_at_iteration_3.png
# Iteration 3 completed in 1s
# Starting iteration 4 of 10
# Current loss value: 978712770.0  Improvement : 17.752 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/2_gen_at_iteration_4.png
# Iteration 4 completed in 1s
# Starting iteration 5 of 10
# Current loss value: 812547840.0  Improvement : 16.978 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/2_gen_at_iteration_5.png
# Iteration 5 completed in 1s
# Starting iteration 6 of 10
# Current loss value: 707114000.0  Improvement : 12.976 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/2_gen_at_iteration_6.png
# Iteration 6 completed in 1s
# Starting iteration 7 of 10
# Current loss value: 609672450.0  Improvement : 13.780 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/2_gen_at_iteration_7.png
# Iteration 7 completed in 1s
# Starting iteration 8 of 10
# Current loss value: 535210140.0  Improvement : 12.213 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/2_gen_at_iteration_8.png
# Iteration 8 completed in 1s
# Starting iteration 9 of 10
# Current loss value: 471177120.0  Improvement : 11.964 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/2_gen_at_iteration_9.png
# Iteration 9 completed in 1s
# Starting iteration 10 of 10
# Current loss value: 417084400.0  Improvement : 11.480 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/2_gen_at_iteration_10.png
# Iteration 10 completed in 1s
# Neural-Style-Transfer/color_transfer.py:116: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   generated_image = imread(args.generated_image, mode="RGB")
# Neural-Style-Transfer/color_transfer.py:119: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   content_image = imread(args.content_image, mode=mode)
# Neural-Style-Transfer/color_transfer.py:120: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
#     Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   content_image = imresize(content_image, (img_width, img_height), interp='bicubic')
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:129: DeprecationWarning:     `imsave` is deprecated!
#     `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imwrite`` instead.
#   imsave(image_path, img)
# Image saved at path : drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/2_gen_at_iteration_10_original_color.png
#
# 33.33% completed...
#
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 2022-01-05 17:46:17.377817: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-01-05 17:46:17.400504: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:46:17.401323: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2022-01-05 17:46:17.401737: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:46:17.403705: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:46:17.404793: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-01-05 17:46:17.405127: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-01-05 17:46:17.407193: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-01-05 17:46:17.408431: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-01-05 17:46:17.412424: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-01-05 17:46:17.412577: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:46:17.413389: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:46:17.414188: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-01-05 17:46:17.419833: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2022-01-05 17:46:17.420077: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55c29d944fc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-01-05 17:46:17.420114: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-01-05 17:46:17.530631: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:46:17.531512: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55c29d945180 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-01-05 17:46:17.531547: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2022-01-05 17:46:17.531790: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:46:17.532458: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2022-01-05 17:46:17.532529: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:46:17.532573: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:46:17.532636: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-01-05 17:46:17.532691: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-01-05 17:46:17.532740: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-01-05 17:46:17.532780: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-01-05 17:46:17.532821: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-01-05 17:46:17.532913: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:46:17.533734: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:46:17.534491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-01-05 17:46:17.534560: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:46:17.535790: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-01-05 17:46:17.535823: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2022-01-05 17:46:17.535845: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2022-01-05 17:46:17.535981: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:46:17.536770: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:46:17.537507: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-01-05 17:46:17.537559: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10813 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Model loaded.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Starting iteration 1 of 10
# 2022-01-05 17:46:22.426625: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:46:22.572371: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Current loss value: 3305626600.0  Improvement : 0.000 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/3_gen_at_iteration_1.png
# Iteration 1 completed in 3s
# Starting iteration 2 of 10
# Current loss value: 1748689800.0  Improvement : 47.100 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/3_gen_at_iteration_2.png
# Iteration 2 completed in 1s
# Starting iteration 3 of 10
# Current loss value: 1249033600.0  Improvement : 28.573 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/3_gen_at_iteration_3.png
# Iteration 3 completed in 1s
# Starting iteration 4 of 10
# Current loss value: 1000408960.0  Improvement : 19.905 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/3_gen_at_iteration_4.png
# Iteration 4 completed in 1s
# Starting iteration 5 of 10
# Current loss value: 840921500.0  Improvement : 15.942 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/3_gen_at_iteration_5.png
# Iteration 5 completed in 1s
# Starting iteration 6 of 10
# Current loss value: 741907840.0  Improvement : 11.774 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/3_gen_at_iteration_6.png
# Iteration 6 completed in 1s
# Starting iteration 7 of 10
# Current loss value: 675250200.0  Improvement : 8.985 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/3_gen_at_iteration_7.png
# Iteration 7 completed in 1s
# Starting iteration 8 of 10
# Current loss value: 624401660.0  Improvement : 7.530 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/3_gen_at_iteration_8.png
# Iteration 8 completed in 1s
# Starting iteration 9 of 10
# Current loss value: 583683140.0  Improvement : 6.521 %
# Rescaling Image to (85, 85)
# ...
# Iteration 7 completed in 1s
# Starting iteration 8 of 10
# Current loss value: 440406100.0  Improvement : 6.666 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/7_gen_at_iteration_8.png
# Iteration 8 completed in 1s
# Starting iteration 9 of 10
# Current loss value: 415789500.0  Improvement : 5.590 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/7_gen_at_iteration_9.png
# Iteration 9 completed in 1s
# Starting iteration 10 of 10
# Current loss value: 395643800.0  Improvement : 4.845 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/7_gen_at_iteration_10.png
# Iteration 10 completed in 1s
# Neural-Style-Transfer/color_transfer.py:116: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   generated_image = imread(args.generated_image, mode="RGB")
# Neural-Style-Transfer/color_transfer.py:119: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   content_image = imread(args.content_image, mode=mode)
# Neural-Style-Transfer/color_transfer.py:120: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
#     Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   content_image = imresize(content_image, (img_width, img_height), interp='bicubic')
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:129: DeprecationWarning:     `imsave` is deprecated!
#     `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imwrite`` instead.
#   imsave(image_path, img)
# Image saved at path : drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/7_gen_at_iteration_10_original_color.png
#
# 88.89% completed...
#
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 2022-01-05 17:48:16.690842: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-01-05 17:48:16.711467: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:48:16.712352: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2022-01-05 17:48:16.712726: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:48:16.714688: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:48:16.715763: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-01-05 17:48:16.716115: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-01-05 17:48:16.718117: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-01-05 17:48:16.719303: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-01-05 17:48:16.723392: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-01-05 17:48:16.723506: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:48:16.724287: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:48:16.724959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-01-05 17:48:16.730510: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2022-01-05 17:48:16.730859: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55a5c2ab0fc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-01-05 17:48:16.730899: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-01-05 17:48:16.825744: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:48:16.826572: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55a5c2ab1180 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-01-05 17:48:16.826640: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2022-01-05 17:48:16.826843: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:48:16.827585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2022-01-05 17:48:16.827670: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:48:16.827742: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:48:16.827799: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-01-05 17:48:16.827854: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-01-05 17:48:16.827904: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-01-05 17:48:16.827946: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-01-05 17:48:16.827989: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-01-05 17:48:16.828091: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:48:16.828844: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:48:16.829534: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2022-01-05 17:48:16.829634: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-01-05 17:48:16.830816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-01-05 17:48:16.830853: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2022-01-05 17:48:16.830873: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2022-01-05 17:48:16.831045: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:48:16.831760: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-05 17:48:16.832464: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-01-05 17:48:16.832517: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10813 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Model loaded.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Starting iteration 1 of 10
# 2022-01-05 17:48:21.782504: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-01-05 17:48:21.937106: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Current loss value: 2918898000.0  Improvement : 0.000 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/8_gen_at_iteration_1.png
# Iteration 1 completed in 3s
# Starting iteration 2 of 10
# Current loss value: 1434072000.0  Improvement : 50.869 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/8_gen_at_iteration_2.png
# Iteration 2 completed in 1s
# Starting iteration 3 of 10
# Current loss value: 942552450.0  Improvement : 34.274 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/8_gen_at_iteration_3.png
# Iteration 3 completed in 1s
# Starting iteration 4 of 10
# Current loss value: 727040200.0  Improvement : 22.865 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/8_gen_at_iteration_4.png
# Iteration 4 completed in 1s
# Starting iteration 5 of 10
# Current loss value: 613717500.0  Improvement : 15.587 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/8_gen_at_iteration_5.png
# Iteration 5 completed in 1s
# Starting iteration 6 of 10
# Current loss value: 544514940.0  Improvement : 11.276 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/8_gen_at_iteration_6.png
# Iteration 6 completed in 1s
# Starting iteration 7 of 10
# Current loss value: 477217340.0  Improvement : 12.359 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/8_gen_at_iteration_7.png
# Iteration 7 completed in 1s
# Starting iteration 8 of 10
# Current loss value: 431244000.0  Improvement : 9.634 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/8_gen_at_iteration_8.png
# Iteration 8 completed in 1s
# Starting iteration 9 of 10
# Current loss value: 391196740.0  Improvement : 9.286 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/8_gen_at_iteration_9.png
# Iteration 9 completed in 1s
# Starting iteration 10 of 10
# Current loss value: 360157020.0  Improvement : 7.935 %
# Rescaling Image to (85, 85)
# Image saved as drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/8_gen_at_iteration_10.png
# Iteration 10 completed in 1s
# Neural-Style-Transfer/color_transfer.py:116: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   generated_image = imread(args.generated_image, mode="RGB")
# Neural-Style-Transfer/color_transfer.py:119: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   content_image = imread(args.content_image, mode=mode)
# Neural-Style-Transfer/color_transfer.py:120: DeprecationWarning:     `imresize` is deprecated!
#     `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
#     Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   content_image = imresize(content_image, (img_width, img_height), interp='bicubic')
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:58: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode='RGB'), mode=mode)  # Convert to YCbCr color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:78: DeprecationWarning:     `fromimage` is deprecated!
#     `fromimage` is deprecated in SciPy 1.0.0. and will be removed in 1.2.0.
#     Use ``np.asarray(im)`` instead.
#   generated = fromimage(toimage(generated, mode=mode), mode='RGB')  # Convert to RGB color space
# Neural-Style-Transfer/color_transfer.py:129: DeprecationWarning:     `imsave` is deprecated!
#     `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imwrite`` instead.
#   imsave(image_path, img)
# Image saved at path : drive/MyDrive/_Van_Gogh/results/result_00440_6/generated/8_gen_at_iteration_10_original_color.png
#
# 100.00% completed!
#
# Reconstructing images...
#
# Done!

# %% [markdown]
# # Results visualization

# %%
for f in folders:
  num = f[f.index('_')+1:]
  reconstr_dir = os.path.join(base_dir, f, 'reconstructed')

  content_img = Image.open(os.path.join(base_dir, f, num + '.jpg'))
  style_img = Image.open(os.path.join(base_dir, f, num + '_style.jpg'))
  result_no_color = Image.open(os.path.join(reconstr_dir, num + '_transferred_iteration_%d.jpg' % (NUM_ITERATIONS)))
  result_color = Image.open(os.path.join(reconstr_dir, num + '_color_transfer.jpg'))

  print("Image no. " + num)
  print("Content:")
  show_img(content_img)
  print("Style:")
  show_img(style_img)
  print("Result (no color transfer):")
  show_img(result_no_color)
  print("Result (with color transfer):")
  show_img(result_color)
  print()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
